# %%
a=10 
b=3 
print (a+b)
print (a-b)
print (a*b)
print (a/b)
print (a%b) #return remainder
print (a//b) #return quotient
print (a**b) #return power
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 3
# 1000

# %%
a=10
a//=5
print(a)
# Out:
# 2

# %%
print(a==5) #return true if equal
print(a!=5) #return true if not equal
print(a>5) #return true if greater than
print(a<5) #return true if less than
print(a>=5) #return true if greater than or equal
print(a<=5) #return true if less than or equal
# Out:
# False
# True
# False
# True
# False
# True

# %%
a=10
a+=5
print(a)
# Out:
# 15

# %%
a=10
a-=5
print(a)
# Out:
# 5

# %%
x=10
y=5
z=7
x>y and y>z
# Out:
# False

# %%
x>y or y>z
# Out:
# True

# %%
email= "saxenaakshat40@gmail.com"
'&' in email
# Out:
# False
