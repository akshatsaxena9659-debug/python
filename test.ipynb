# %%
x = 10 
y = 5 
if x > 5 == y:
    print ("match")
else:
    print("Not match")
# Out:
# match

# %%
a = [1,2,3]
b=a 
a=a+[4]
print(b)
# Out:
# [1, 2, 3]

# %%
for i in range(3):
    if i == 2:
        break
    else:
        print("completed")
# Out:
# completed
# completed

# %%
a = {1,2,3}
b =a 
a.clear()
print(b)
# Out:
# set()

# %%
a=[[1,2]]*3
a[0][0]=100
print(a)
# Out:
# [[100, 2], [100, 2], [100, 2]]

# %%
def append_twice(val , lst=[]):
    lst.append(val)
    lst.append(val)
    return lst 
print (append_twice(1))
print (append_twice(2))
# Out:
# [1, 1]
# [1, 1, 2, 2]

# %%
a =
