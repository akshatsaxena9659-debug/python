# %%
#multiline string 
poem = ''' jonny jonny yes papa
eating sugar no papa'''
print(poem)
# Out:
#  jonny jonny yes papa
# eating sugar no papa

# %%
#list can store diffrent data types but array can store only one data type.

# %%
lst =[ "banana" , "apple" , "orange"] #list is a collection of ordered elements
print(lst)
# Out:
# ['banana', 'apple', 'orange']

# %%
lst=(2,3,4,2,5,6,7,5,4,2,9,5,4,2,5) #tuple is a collection of ordered elements
print (lst)
# Out:
# (2, 3, 4, 2, 5, 6, 7, 5, 4, 2, 9, 5, 4, 2, 5)

# %%
lst={2,3,4,2,5,6,7,5,4,2,9,5,4,2,5} #set is a collection of unique elements
print (lst)
# Out:
# {2, 3, 4, 5, 6, 7, 9}

# %%
student ={"name":"akshat",
         "age":20,  
         "course":"python"
         }
print(student)
# Out:
# {'name': 'akshat', 'age': 20, 'course': 'python'}

# %% [markdown]
# TYPE CASTING process of converting one datatype into another

# %%
a=int(input("enter a number")) #string to integer conversion
b=int(input("enter a number"))
print(a+b)
# Out:
# 30
