# %%
name = "AKSHAT"
print(name[0:3])
# Out:
# AKS

# %%
x="heyy"
y="hello"
print(x+y) #string concatenation
# Out:
# heyyhello

# %%
a="heyy"
print(a*5) #string repetition
# Out:
# heyyheyyheyyheyyheyy

# %%
x.capitalize()
# Out:
# 'Heyy'

# %%
x.lower()
# Out:
# 'heyy'

# %%
x.upper()
# Out:
# 'HEYY'

# %%
a="all is well "
a.title()
# Out:
# 'All Is Well '

# %%
poem = ''' Johhny Johhny Yes Papa
Eating sugar No Papa             
telling lies No Papa
Open your mouth Ha Ha Ha '''
print(poem)
# Out:
#  Johhny Johhny Yes Papa
# Eating sugar No Papa
# telling lies No Papa
# Open your mouth Ha Ha Ha

# %%
p=poem.replace("papa","mama").replace("Ha Ha Ha","Ho Ho Ho").replace("Johhny","Bobby")
print(p)
# Out:
#  Bobby Bobby Yes Papa
# Eating sugar No Papa
# telling lies No Papa
# Open your mouth Ho Ho Ho

# %%
poem.split()
# Out:
# ['Johhny',
#  'Johhny',
#  'Yes',
#  'Papa',
#  'Eating',
#  'sugar',
#  'No',
#  'Papa',
#  'telling',
#  'lies',
#  'No',
#  'Papa',
#  'Open',
#  'your',
#  'mouth',
#  'Ha',
#  'Ha',
#  'Ha']

# %%
p.splitlines()
# Out:
# [' Bobby Bobby Yes Papa',
#  'Eating sugar No Papa             ',
#  'telling lies No Papa',
#  'Open your mouth Ho Ho Ho ']

# %%
poem.find("Johhny")
# Out:
# 1

# %%
text =" hello "
text.strip() #removes whitespace from the beginning and end of the string
# Out:
# 'hello'

# %%
a.count("l") #counts the number of occurences of a substring in the string
# Out:
# 4

# %%
a.startswith("a") #checks if the string starts with the specified substring
a.endswith("a") #checks if the string ends with the specified substring
# Out:
# False

# %%
"hello".isalpha() #checks if all characters in the string are alphabetic
# Out:
# True

# %%
"Hello World".swapcase() #converts uppercase characters to lowercase and vice versa
# Out:
# 'hELLO wORLD'

# %%
"123".isdigit() #checks if all characters in the string are digits
# Out:
# True

# %%
"hellow123".isalnum() #checks if all characters in the string are alphanumeric
# Out:
# True

# %%
"hello".index("e") #returns the index of the first occurrence of the specified substring in the string
# Out:
# 1
